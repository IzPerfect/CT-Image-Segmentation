# %%
import keras
from keras import models
from keras.layers import Dense, Dropout, Flatten, Activation, Lambda, Conv2D, MaxPooling2D, UpSampling2D
from keras.optimizers import Adam
from keras.layers.normalization import BatchNormalization

from data_utils import *
import matplotlib.pyplot as plt
import numpy as np
import os
import time
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
x_train = np.load('./dataset/x_train.npy')
y_train = np.load('./dataset/y_train.npy')
x_test = np.load('./dataset/x_test.npy')
y_test = np.load('./dataset/y_test.npy')

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (213, 128, 128, 1) (213, 128, 128, 1)
# (54, 128, 128, 1) (54, 128, 128, 1)

# %% [markdown]
# # Segmentation Class

# %%
class SegCAE(object):
    def __init__(self, img_shape, actf = 'relu',
        learning_rate = 0.001,  drop_rate = 0.5, do_batch_norm = False, do_drop = False):

        self.learning_rate = learning_rate
        self.actf = actf
        self.img_shape = img_shape
        self.drop_rate = drop_rate
        self.do_batch_norm = do_batch_norm
        self.do_drop = do_drop

        self.model = self.build_model()

    def cae_data_input(self, x):
        return x

    def cae_shape(self, input_shape):
        return (input_shape[0], input_shape[1], input_shape[2])
    
    
    # encoder
    def encoding_path(self, model):    
        model.add(Conv2D(16, (3,3), strides = 1,  padding = 'same', kernel_initializer = 'he_normal'))
        model.add(BatchNormalization()) if self.do_batch_norm else None
        model.add(Activation(self.actf))
        model.add(MaxPooling2D((2,2), strides = (2,2)))
                  
        model.add(Conv2D(32, (3,3), strides = 1,  padding = 'same', kernel_initializer = 'he_normal'))
        model.add(BatchNormalization()) if self.do_batch_norm else None
        model.add(Activation(self.actf))
        model.add(MaxPooling2D((2,2), strides = (2,2)))     
                  
        model.add(Conv2D(64, (3,3), strides = 1,  padding = 'same', kernel_initializer = 'he_normal'))
        model.add(BatchNormalization()) if self.do_batch_norm else None
        model.add(Activation(self.actf))
        model.add(MaxPooling2D((2,2), strides = (2,2))) 
                  
        
        return model
                  
    # decoder
    def decoding_path(self, model):    
        model.add(Conv2D(64, (3,3), strides = 1,  padding = 'same', kernel_initializer = 'he_normal'))
        model.add(BatchNormalization()) if self.do_batch_norm else None
        model.add(Activation(self.actf))
        model.add(UpSampling2D((2,2)))
                  
        model.add(Conv2D(32, (3,3), strides = 1,  padding = 'same', kernel_initializer = 'he_normal'))
        model.add(BatchNormalization()) if self.do_batch_norm else None
        model.add(Activation(self.actf))
        model.add(UpSampling2D((2,2)))
                  
        model.add(Conv2D(16, (3,3), strides = 1,  padding = 'same', kernel_initializer = 'he_normal'))
        model.add(BatchNormalization()) if self.do_batch_norm else None
        model.add(Activation(self.actf))
        model.add(UpSampling2D((2,2)))     
                  
        model.add(Conv2D(1, (3,3), strides = 1,  padding = 'same', kernel_initializer = 'he_normal'))
        model.add(Activation('sigmoid'))
        
        return model
    # build network
    def build_model(self):
        model = models.Sequential()

        model.add(Lambda(self.cae_data_input, input_shape = self.img_shape))
    
        model = self.encoding_path(model)
         
        model.add(Conv2D(128, (3,3), strides = 1,  padding = 'same', kernel_initializer = 'he_normal'))
        model.add(Dropout(self.drop_rate)) if self.do_drop else None
        
        model = self.decoding_path(model)
        

        model.compile(loss = 'binary_crossentropy', optimizer = Adam(lr = self.learning_rate)
                          ,metrics = ['accuracy', 'mse'])
        
        return model

    # train model
    def train(self, X_train, Y_train, epoch = 10, batch_size = 32, val_split = 0.2):
      
        self.history = self.model.fit(X_train, Y_train, validation_split = val_split, 
                                          epochs = epoch, batch_size = batch_size)


        return self.history

    # evalutate model
    def show_eval(self, X_test, Y_test, batch_test_size = 10):
        self.score = self.model.evaluate(X_test, Y_test, batch_size = batch_test_size)
        print('Test Loss : ', self.score[0])
        print('Test Accuracy : ', self.score[1])

        return self.score

    def predict(self, X_test):
        pred_classes = self.model.predict(X_test)

        return pred_classes

    def show_model(self):
        return print(self.model.summary())

# %%
seg_model = SegCAE(x_train[0].shape, do_batch_norm = True, do_drop = True)

# %%
seg_model.show_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 128, 128, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      160
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 16)      64
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 16)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        73792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 16)        4624
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64, 64, 16)        64
# _________________________________________________________________
# activation_6 (Activation)    (None, 64, 64, 16)        0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 128, 1)       145
# _________________________________________________________________
# activation_7 (Activation)    (None, 128, 128, 1)       0
# =================================================================
# Total params: 195,073
# Trainable params: 194,625
# Non-trainable params: 448
# _________________________________________________________________
# None

# %% [markdown]
# # Train Model

# %%
history = seg_model.train(x_train, y_train, epoch = 100)
# Out:
# Train on 170 samples, validate on 43 samples
# Epoch 1/100
# 170/170 [==============================] - 21s 123ms/step - loss: 0.5247 - acc: 0.7529 - mean_squared_error: 0.1713 - val_loss: 0.5029 - val_acc: 0.7563 - val_mean_squared_error: 0.1627
# Epoch 2/100
# 170/170 [==============================] - 25s 147ms/step - loss: 0.3610 - acc: 0.8998 - mean_squared_error: 0.1035 - val_loss: 0.3812 - val_acc: 0.8102 - val_mean_squared_error: 0.1168
# Epoch 3/100
# 170/170 [==============================] - 24s 142ms/step - loss: 0.2759 - acc: 0.9330 - mean_squared_error: 0.0705 - val_loss: 0.2432 - val_acc: 0.9079 - val_mean_squared_error: 0.0651
# Epoch 4/100
# 170/170 [==============================] - 20s 120ms/step - loss: 0.2197 - acc: 0.9467 - mean_squared_error: 0.0519 - val_loss: 0.2310 - val_acc: 0.9049 - val_mean_squared_error: 0.0636
# Epoch 5/100
# 170/170 [==============================] - 23s 138ms/step - loss: 0.1772 - acc: 0.9516 - mean_squared_error: 0.0398 - val_loss: 0.1525 - val_acc: 0.9462 - val_mean_squared_error: 0.0363
# Epoch 6/100
# 170/170 [==============================] - 21s 121ms/step - loss: 0.1481 - acc: 0.9548 - mean_squared_error: 0.0328 - val_loss: 0.1426 - val_acc: 0.9505 - val_mean_squared_error: 0.0332
# Epoch 7/100
# 170/170 [==============================] - 24s 141ms/step - loss: 0.1281 - acc: 0.9588 - mean_squared_error: 0.0280 - val_loss: 0.1174 - val_acc: 0.9597 - val_mean_squared_error: 0.0262
# Epoch 8/100
# 170/170 [==============================] - 23s 135ms/step - loss: 0.1160 - acc: 0.9591 - mean_squared_error: 0.0261 - val_loss: 0.1152 - val_acc: 0.9593 - val_mean_squared_error: 0.0261
# Epoch 9/100
# 170/170 [==============================] - 23s 134ms/step - loss: 0.1068 - acc: 0.9610 - mean_squared_error: 0.0242 - val_loss: 0.1083 - val_acc: 0.9615 - val_mean_squared_error: 0.0244
# Epoch 10/100
# 170/170 [==============================] - 24s 142ms/step - loss: 0.0991 - acc: 0.9625 - mean_squared_error: 0.0227 - val_loss: 0.1119 - val_acc: 0.9595 - val_mean_squared_error: 0.0256
# Epoch 11/100
# 170/170 [==============================] - 25s 144ms/step - loss: 0.0935 - acc: 0.9644 - mean_squared_error: 0.0213 - val_loss: 0.1000 - val_acc: 0.9644 - val_mean_squared_error: 0.0223
# Epoch 12/100
# 170/170 [==============================] - 20s 118ms/step - loss: 0.0862 - acc: 0.9665 - mean_squared_error: 0.0196 - val_loss: 0.1195 - val_acc: 0.9539 - val_mean_squared_error: 0.0293
# Epoch 13/100
# 170/170 [==============================] - 23s 138ms/step - loss: 0.0825 - acc: 0.9678 - mean_squared_error: 0.0186 - val_loss: 0.0979 - val_acc: 0.9639 - val_mean_squared_error: 0.0222
100
# 170/170 [==============================] - 23s 133ms/step - loss: 0.0321 - acc: 0.9818 - mean_squared_error: 0.0072 - val_loss: 0.0866 - val_acc: 0.9712 - val_mean_squared_error: 0.0167
# Epoch 87/100
# 170/170 [==============================] - 22s 132ms/step - loss: 0.0319 - acc: 0.9816 - mean_squared_error: 0.0072 - val_loss: 0.0824 - val_acc: 0.9752 - val_mean_squared_error: 0.0141
# Epoch 88/100
# 170/170 [==============================] - 20s 115ms/step - loss: 0.0297 - acc: 0.9826 - mean_squared_error: 0.0066 - val_loss: 0.0847 - val_acc: 0.9753 - val_mean_squared_error: 0.0141
# Epoch 89/100
# 170/170 [==============================] - 22s 132ms/step - loss: 0.0297 - acc: 0.9827 - mean_squared_error: 0.0065 - val_loss: 0.0871 - val_acc: 0.9745 - val_mean_squared_error: 0.0145
# Epoch 90/100
# 170/170 [==============================] - 21s 123ms/step - loss: 0.0291 - acc: 0.9828 - mean_squared_error: 0.0064 - val_loss: 0.0861 - val_acc: 0.9742 - val_mean_squared_error: 0.0147
# Epoch 91/100
# 170/170 [==============================] - 23s 132ms/step - loss: 0.0286 - acc: 0.9829 - mean_squared_error: 0.0062 - val_loss: 0.0846 - val_acc: 0.9761 - val_mean_squared_error: 0.0134
# Epoch 92/100
# 170/170 [==============================] - 21s 122ms/step - loss: 0.0285 - acc: 0.9829 - mean_squared_error: 0.0063 - val_loss: 0.0858 - val_acc: 0.9752 - val_mean_squared_error: 0.0141
# Epoch 93/100
# 170/170 [==============================] - 23s 133ms/step - loss: 0.0284 - acc: 0.9830 - mean_squared_error: 0.0062 - val_loss: 0.0873 - val_acc: 0.9740 - val_mean_squared_error: 0.0149
# Epoch 94/100
# 170/170 [==============================] - 23s 133ms/step - loss: 0.0281 - acc: 0.9830 - mean_squared_error: 0.0062 - val_loss: 0.0863 - val_acc: 0.9757 - val_mean_squared_error: 0.0137
# Epoch 95/100
# 170/170 [==============================] - 20s 119ms/step - loss: 0.0282 - acc: 0.9830 - mean_squared_error: 0.0062 - val_loss: 0.0915 - val_acc: 0.9733 - val_mean_squared_error: 0.0154
# Epoch 96/100
# 170/170 [==============================] - 23s 133ms/step - loss: 0.0277 - acc: 0.9833 - mean_squared_error: 0.0060 - val_loss: 0.0847 - val_acc: 0.9758 - val_mean_squared_error: 0.0137
# Epoch 97/100
# 170/170 [==============================] - 23s 133ms/step - loss: 0.0276 - acc: 0.9833 - mean_squared_error: 0.0060 - val_loss: 0.0873 - val_acc: 0.9737 - val_mean_squared_error: 0.0150
# Epoch 98/100
# 170/170 [==============================] - 21s 122ms/step - loss: 0.0290 - acc: 0.9828 - mean_squared_error: 0.0064 - val_loss: 0.0933 - val_acc: 0.9703 - val_mean_squared_error: 0.0178
# Epoch 99/100
# 170/170 [==============================] - 22s 127ms/step - loss: 0.0294 - acc: 0.9826 - mean_squared_error: 0.0066 - val_loss: 0.0884 - val_acc: 0.9745 - val_mean_squared_error: 0.0145
# Epoch 100/100
# 170/170 [==============================] - 22s 132ms/step - loss: 0.0307 - acc: 0.9821 - mean_squared_error: 0.0069 - val_loss: 0.0932 - val_acc: 0.9726 - val_mean_squared_error: 0.0160

# %%
plot_acc(history)

# %%
plot_loss(history)

# %% [markdown]
# # Show result

# %%
preds = seg_model.predict(x_test)

# %%
show_num = 10
fig, ax = plt.subplots(show_num, 3, figsize=(15, 50))

for i, pred in enumerate(preds[:show_num]):
    ax[i, 0].imshow(x_test[i].squeeze(), cmap='gray')
    ax[i, 1].imshow(y_test[i].squeeze(), cmap='gray')
    ax[i, 2].imshow(pred.squeeze(), cmap='gray')
